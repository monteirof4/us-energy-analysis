# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
state_coordinates = "/Users/admin/Desktop/Project-2_US Engery/us-energy-analysis/assets/data/EIA_Project_Data/statelatlong.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
state_coordinates_df = pd.read_csv(state_coordinates, encoding="ISO-8859-1")

# %%
# Show just the header
state_coordinates_df.head()
# Out:
#   Abbreviation   Latitude   Longitude    US_State
# 0           AL  32.601011  -86.680736     Alabama
# 1           AK  61.302501 -158.775020      Alaska
# 2           AZ  34.168219 -111.930907     Arizona
# 3           AR  34.751928  -92.131378    Arkansas
# 4           CA  37.271875 -119.270415  California

# %%
# rename columns
state_coordinates_df = state_coordinates_df.rename(columns={'State': 'Abbreviation', 'City': 'US_State'})
state_coordinates_df.head()
# Out:
#   Abbreviation   Latitude   Longitude    US_State
# 0           AL  32.601011  -86.680736     Alabama
# 1           AK  61.302501 -158.775020      Alaska
# 2           AZ  34.168219 -111.930907     Arizona
# 3           AR  34.751928  -92.131378    Arkansas
# 4           CA  37.271875 -119.270415  California

# %%
# export dataframe to csv file
#state_coordinates_df.to_csv("state_coordinates.csv", index=False, header=True)

# %%
import sqlite3

# %%
conn = sqlite3.connect('/Users/admin/Desktop/Project-2_US Engery/us-energy-analysis/assets/db/us_energy.sqlite')

# %%
state_coordinates_df.to_sql('state_coordinates', conn, if_exists='replace', index=False)

# %%
pd.read_sql('select * from state_coordinates', conn)
# Out:
#    Abbreviation   Latitude   Longitude              US_State
# 0            AL  32.601011  -86.680736               Alabama
# 1            AK  61.302501 -158.775020                Alaska
# 2            AZ  34.168219 -111.930907               Arizona
# 3            AR  34.751928  -92.131378              Arkansas
# 4            CA  37.271875 -119.270415            California
# 5            CO  38.997934 -105.550567              Colorado
# 6            CT  41.518784  -72.757507           Connecticut
# 7            DE  39.145251  -75.418921              Delaware
# 8            DC  38.899349  -77.014567  District of Columbia
# 9            FL  27.975728  -83.833017               Florida
# 10           GA  32.678125  -83.222976               Georgia
# 11           HI  20.460000 -157.505000                Hawaii
# 12           ID  45.494576 -114.142430                 Idaho
# 13           IL  39.739318  -89.504139              Illinois
# ...

# %%
# Store filepath in a variable
final_combine_table = "/Users/admin/Desktop/Project-2_US Engery/us-energy-analysis/assets/data/EIA_Project_Data/final_combine_table.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
final_combine_table_df = pd.read_csv(final_combine_table, encoding="ISO-8859-1")

# %%
# Show just the header
final_combine_table_df.head()
# Out:
#   State  Year  Total_co2_emission                 CO2_Unit  Average_Price  \
# 0    AL  2016          115.088298  million metric tons CO2          14.81
# 1    AL  2015          120.142812  million metric tons CO2          15.68
# 2    AL  2014          123.161802  million metric tons CO2          18.62
# 3    AL  2013          120.908517  million metric tons CO2          18.89
# 4    AL  2012          123.201027  million metric tons CO2          19.86
#
#                 Price_Unit  resident_population  Pop_Unit  Total_energy  \
# 0  Dollars per million Btu                 4865  Thousand       1124482
# 1  Dollars per million Btu                 4853  Thousand       1269743
# 2  Dollars per million Btu                 4842  Thousand       1367345
# 3  Dollars per million Btu                 4830  Thousand       1478402
# 4  Dollars per million Btu                 4816  Thousand       1443558
#
#    ENERGY_Unit  Total_renewable_energy   Renew_Unit
# ...

# %%
conn = sqlite3.connect('/Users/admin/Desktop/Project-2_US Engery/us-energy-analysis/assets/db/us_energy.sqlite')

# %%
final_combine_table_df.to_sql('final_combine_table', conn, if_exists='replace', index=False)

# %%
pd.read_sql('select * from final_combine_table', conn)
# Out:
#      State  Year  Total_co2_emission                 CO2_Unit  Average_Price  \
# 0       AL  2016          115.088298  million metric tons CO2          14.81
# 1       AL  2015          120.142812  million metric tons CO2          15.68
# 2       AL  2014          123.161802  million metric tons CO2          18.62
# 3       AL  2013          120.908517  million metric tons CO2          18.89
# 4       AL  2012          123.201027  million metric tons CO2          19.86
# 5       AL  2011          129.930038  million metric tons CO2          20.06
# 6       AL  2010          132.767419  million metric tons CO2          17.80
# 7       AL  2009          120.100202  million metric tons CO2          16.55
# 8       AL  2008          139.628142  million metric tons CO2          19.22
# 9       AL  2007          147.430252  million metric tons CO2          16.06
# 10      AL  2006          145.782018  million metric tons CO2          14.96
# ...
